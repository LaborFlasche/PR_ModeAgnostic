# %% [markdown]
# # pydvl — Shapley on Data Points

# %% [markdown]
# ## Quantitative Research Question
#
# #### *For a small subset (e.g. 200 training points) and a custom shapiq game, how long does it take to reach a fixed error against a high-budget reference for pyDVL's `Truncated Monte Carlo` vs. shapiq's `PermutationSamplingSV` (overhead cost of shapiq's general-purpose game abstraction) and pyDVL's `Permutation Monte Carlo` (value of data-valuation-specific algorithmic refinements)?*
